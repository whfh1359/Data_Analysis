# %% [markdown]
# ## 서울시에서 공개한 코로나19 발생동향 분석
# * http://www.seoul.go.kr/coronaV/coronaStatus.do

# %%
# 필요한 라이브러리를 불러옵니다.
import pandas as pd
import numpy as np

# %%
# 크롤링으로 가져올 url 주소를 입력합니다.
url = "http://www.seoul.go.kr/coronaV/coronaStatus.do"
url
# Out:
# 'http://www.seoul.go.kr/coronaV/coronaStatus.do'

# %%
"""
최근 확진자가 증가하면서 read_html 로 데이터를 불러올 때 3~5분 정도의 시간이 소요됩니다.
최대 10분까지 걸릴 수 있으며 오류 메시지가 표시되지 않는 한 데이터가 로드 될 때까지 기다려주세요! 
"""
# Out:
# '\n최근 확진자가 증가하면서 read_html 로 데이터를 불러올 때 3~5분 정도의 시간이 소요됩니다.\n최대 10분까지 걸릴 수 있으며 오류 메시지가 표시되지 않는 한 데이터가 로드 될 때까지 기다려주세요! \n'

# %%
# 판다스의 read_html 을 통해 위 url에 있는 불러옵니다.
table = pd.read_html(url)
len(table)
# Out:
# 5

# %%
# read_html 은 사이트 내의 html 태그를 불러옵니다.
table[2].T   #table.transpose() 해도 된다.
#table[1], table[2], table[3], table[4] 다 보면서 무엇인지 확인해보기.
#4번이 홈페이지와 비슷하고 더 자세하므로 5번 말고 table[4]로 할 것.
# Out:
#                     0
# 소계               5443
# 해외접촉관련            421
# 영등포구 방문판매 업체 관련     7
# 도봉구 다나 병원          50
# 서초구 병원 관련           3
# 강남구 대우디오빌 플러스      29
# 영등포구 LG 트윈타워        7
# 강북구 북서울 꿈의교회        6
# 서초구 소재 카페           3
# 동작구 부동산 회사          2
# 관악구 휘트니스 관련         4
# 마포구 서울디자인 고등학교      7
# 도봉구 예마루데이케어센터      30
# 관악구 삼모 스포렉스        26
# 서대문구 세브란스 병원       37
# 강남구 K보건 산업         37
# 성북구 사랑제일교회        641
# 8·15 서울도심 집회      126
# 타 시·도 확진자 접촉자     239
# 기타               2824
# 감염경로 조사중          944

# %%
# table 변수 안에 있는 table 태그의 값을 하나씩 읽어보며 확진자 목록이 있는 테이블을 가져옵니다.
df = table[4]
df.shape
# Out:
# (5443, 6)

# %%
# 미리보기 합니다.
df.head()
# Out:
#                                                   연번   환자번호           감염경로  \
# 0  5443  <tr>  <td class="tdl" colspan="5">  <p>확...  24333       도봉구 다나병원
# 1  5442  <tr>  <td class="tdl" colspan="5">  <p>확...  24321  해외 접촉 추정(프랑스)
# 2  5441  <tr>  <td class="tdl" colspan="5">  <p>확...  24326   강북구 북서울 꿈의교회
# 3  5440  <tr>  <td class="tdl" colspan="5">  <p>확...  24331      기타 확진자 접촉
# 4  5439  <tr>  <td class="tdl" colspan="5">  <p>확...  24330       감염경로 조사중
#
#      확진일   거주지 퇴원현황
# 0  10/06   강북구  NaN
# 1  10/06   용산구  NaN
# 2  10/06   강북구  NaN
# 3  10/06  동대문구  NaN
# 4  10/06  동대문구  NaN

# %%
# 마지막 확진일을 파일명에 써주기 위해 . 을 _ 로 변경합니다.
# 확장자와 구분이 쉽게 되도록 _ 로 변경합니다. 
# df.loc[0] --> index로 가져올 수 있다. 여기에서 확진일만 가지고 오고 싶으므로 확진일만 본다.
last_day = df.loc[0, "확진일"]
#last_day 
last_day = last_day.replace("/", "_") 
last_day
# Out:
# '10_06'

# %%
# 파일명을 만들어 줍니다.
# python에 format string을 사용한다. file_name= f"{last_day}"
# file_name
file_name = f"seoul_covid_{last_day}.csv"
file_name
# Out:
# 'seoul_covid_10_06.csv'

# %%
# csv 파일로 저장한다.
df.to_csv(file_name, index=False) 
# index=False를 안하면 unnamed이라는 index column이 생긴다
# df.to_csv(file_name, index=False, encoding = "cp949")
# 하지만 excel로 저장할 경우가 아니면 미리보기를 할 때 보통 UTF-8 을 쓰므로 옵션지정 X

# %%
# 제대로 저장되었는지 확인한다.
pd.read_csv(file_name)
# read할 때 cp949로 저장했으면 cp949로 읽어야 한다.
# df.to_csv(file_name, index=False, encoding = "cp949")
# Out:
#                                                      연번   환자번호  \
# 0     5443  <tr>  <td class="tdl" colspan="5">  <p>확...  24333
# 1     5442  <tr>  <td class="tdl" colspan="5">  <p>확...  24321
# 2     5441  <tr>  <td class="tdl" colspan="5">  <p>확...  24326
# 3     5440  <tr>  <td class="tdl" colspan="5">  <p>확...  24331
# 4     5439  <tr>  <td class="tdl" colspan="5">  <p>확...  24330
# 5     5438  <tr>  <td class="tdl" colspan="5">  <p>확...  24314
# 6     5437  <tr>  <td class="tdl" colspan="5">  <p>확...  24304
# 7     5436  <tr>  <td class="tdl" colspan="5">  <p>확...  24272
# 8     5435  <tr>  <td class="tdl" colspan="5">  <p>확...  24324
# 9     5434  <tr>  <td class="tdl" colspan="5">  <p>확...  24325
# 10    5433  <tr>  <td class="tdl" colspan="5">  <p>확...  24269
# 11    5432  <tr>  <td class="tdl" colspan="5">  <p>확...  24296
# 12    5431  <tr>  <td class="tdl" colspan="5">  <p>확...  24297
# 13    5430  <tr>  <td class="tdl" colspan="5">  <p>확...  24322
# 14    5429  <tr>  <td class="tdl" colspan="5">  <p>확...  24292
# 15    5428  <tr>  <td class="tdl" colspan="5">  <p>확...  24265
# 16    5427  <tr>  <td class="tdl" colspan="5">  <p>확...  24282
# 17    5426  <tr>  <td class="tdl" colspan="5">  <p>확...  24315
# 18    5425  <tr>  <td class="tdl" colspan="5">  <p>확...  24268
# 19    5424  <tr>  <td class="tdl" colspan="5">  <p>확...  24316
# 20    5423  <tr>  <td class="tdl" colspan="5">  <p>확...  24320
# 21    5422  <tr>  <td class="tdl" colspan="5">  <p>확...  24267
# 22    5421  <tr>  <td class="tdl" colspan="5">  <p>확...  24273
# 23    5420  <tr>  <td class="tdl" colspan="5">  <p>확...  24275
# 24    5419  <tr>  <td class="tdl" colspan="5">  <p>확...  24277
# 25    5418  <tr>  <td class="tdl" colspan="5">  <p>확...  24266
# 26    5417  <tr>  <td class="tdl" colspan="5">  <p>확...  24291
# 27    5416  <tr>  <td class="tdl" colspan="5">  <p>확...  24323
# 28    5415  <tr>  <td class="tdl" colspan="5">  <p>확...  24318
# 29    5414  <tr>  <td class="tdl" colspan="5">  <p>확...  24270
# ...                                                 ...    ...
# 5413  30  <tr>  <td class="tdl" colspan="5">  <p>이동경...    780
# 5414  29  <tr>  <td class="tdl" colspan="5">  <p>이동경...    755
# 5415  28  <tr>  <td class="tdl" colspan="5">  <p>이동경...    627
# 5416  27  <tr>  <td class="tdl" colspan="5">  <p>이동경...    593
# 5417  26  <tr>  <td class="tdl" colspan="5">  <p>이동경...    420
# 5418  25  <tr>  <td class="tdl" colspan="5">  <p>이동경...    365
# 5419  24  <tr>  <td class="tdl" colspan="5">  <p>이동경...    348
# 5420  23  <tr>  <td class="tdl" colspan="5">  <p>이동경...    188
# 5421  22  <tr>  <td class="tdl" colspan="5">  <p>이동경...    161
# 5422  21  <tr>  <td class="tdl" colspan="5">  <p>이동경...    136
# 5423  20  <tr>  <td class="tdl" colspan="5">  <p>이동경...    121
# 5424  19  <tr>  <td class="tdl" colspan="5">  <p>이동경...    112
# 5425  18  <tr>  <td class="tdl" colspan="5">  <p>이동경...    111
# 5426  17  <tr>  <td class="tdl" colspan="5">  <p>이동경...     83
# 5427  16  <tr>  <td class="tdl" colspan="5">  <p>이동경...     56
# 5428  15  <tr>  <td class="tdl" colspan="5">  <p>이동경...     40
# 5429  14  <tr>  <td class="tdl" colspan="5">  <p>이동경...     30
# 5430  13  <tr>  <td class="tdl" colspan="5">  <p>이동경...     29
# 5431  12  <tr>  <td class="tdl" colspan="5">  <p>이동경...     24
# 5432  11  <tr>  <td class="tdl" colspan="5">  <p>이동경...     23
# 5433  10  <tr>  <td class="tdl" colspan="5">  <p>이동경...     21
# 5434  9  <tr>  <td class="tdl" colspan="5">  <p>이동경로...     19
# 5435  8  <tr>  <td class="tdl" colspan="5">  <p>이동경로...     13
# 5436  7  <tr>  <td class="tdl" colspan="5">  <p>이동경로...     11
# 5437  6  <tr>  <td class="tdl" colspan="5">  <p>이동경로...     10
# 5438  5  <tr>  <td class="tdl" colspan="5">  <p>이동경로...      9
# 5439  4  <tr>  <td class="tdl" colspan="5">  <p>이동경로...      7
# 5440  3  <tr>  <td class="tdl" colspan="5">  <p>이동경로...      6
# 5441  2  <tr>  <td class="tdl" colspan="5">  <p>이동경로...      5
# 5442  1  <tr>  <td class="tdl" colspan="5">  <p>이동경로...      2
#
#                  감염경로    확진일   거주지 퇴원현황
# 0            도봉구 다나병원  10/06   강북구  NaN
# 1       해외 접촉 추정(프랑스)  10/06   용산구  NaN
# 2        강북구 북서울 꿈의교회  10/06   강북구  NaN
# 3           기타 확진자 접촉  10/06  동대문구  NaN
# 4            감염경로 조사중  10/06  동대문구  NaN
# 5            감염경로 조사중  10/06   관악구  NaN
# 6          타시도 확진자 접촉  10/06  동대문구  NaN
# 7            감염경로 조사중  10/06   송파구  NaN
# 8          타시도 확진자 접촉  10/06   관악구  NaN
# 9          타시도 확진자 접촉  10/06   관악구  NaN
# 10     영등포구 방문판매업체 관련  10/06   도봉구  NaN
# 11      해외 접촉 추정(우간다)  10/06   노원구  NaN
# 12         타시도 확진자 접촉  10/06   노원구  NaN
# 13    강남구 소재 대우디오빌플러스  10/06   타시도  NaN
# 14         타시도 확진자 접촉  10/06   서초구  NaN
# 15           감염경로 조사중  10/06  영등포구  NaN
# 16           감염경로 조사중  10/06   강남구  NaN
# 17           감염경로 조사중  10/05   중랑구  NaN
# 18     영등포구 방문판매업체 관련  10/05  동대문구  NaN
# 19           감염경로 조사중  10/06   중랑구  NaN
# 20     영등포구 방문판매업체 관련  10/06   광진구  NaN
# 21     영등포구 방문판매업체 관련  10/05   광진구  NaN
# 22     영등포구 방문판매업체 관련  10/06  동대문구  NaN
# 23          서초구 병원 관련  10/06   강남구  NaN
# 24       해외 접촉 추정(일본)  10/06   서초구  NaN
# 25           감염경로 조사중  10/06   타시도  NaN
# 26           감염경로 조사중  10/06  동대문구  NaN
# 27         타시도 확진자 접촉  10/06   관악구  NaN
# 28          기타 확진자 접촉  10/06   관악구  NaN
# 29           도봉구 다나병원  10/06    기타  NaN
# ...               ...    ...   ...  ...
# 5413        은평구 병원 관련   2/23   송파구   퇴원
# 5414        은평구 병원 관련   2/26   강동구   퇴원
# 5415        은평구 병원 관련   2/23   종로구   퇴원
# 5416       해외 접촉(베트남)   2/23   강서구   퇴원
# 5417            대구 방문   2/22   서초구   퇴원
# 5418        은평구 병원 관련   2/22   강동구   퇴원
# 5419       타시도 확진자 접촉   2/22   구로구   퇴원
# 5420           신천지 추정   2/21   서초구   퇴원
# 5421        은평구 병원 관련   2/21  서대문구   퇴원
# 5422           #56 접촉   2/20   종로구   퇴원
# 5423       성동구 아파트 관련   2/20   성동구   퇴원
# 5424          #136 접촉   2/20   종로구   퇴원
# 5425           대구 거주자   2/20   타시도   퇴원
# 5426        #6 접촉(추정)   2/20   종로구   퇴원
# 5427           #30 접촉   2/19   종로구   퇴원
# 5428       성동구 아파트 관련   2/19   성동구   퇴원
# 5429           #29 접촉   2/16   종로구   퇴원
# 5430           #83 접촉   2/16   종로구   사망
# 5431      해외 접촉(우한교민)    2/7   타시도   퇴원
# 5432    해외 접촉(중국 우한시)    2/6  서대문구   퇴원
# 5433            #6 접촉    2/5   성북구   퇴원
# 5434      해외 접촉(싱가포르)    2/5   송파구   퇴원
# 5435     해외 접촉(우한 교민)    2/2   타시도   퇴원
# 5436            #6 접촉   1/31   종로구   퇴원
# 5437            #6 접촉   1/31   종로구   퇴원
# 5438            #5 접촉   1/31   성북구   퇴원
# 5439    해외 접촉(중국 우한시)   1/30   마포구   퇴원
# 5440            #3 접촉   1/30   종로구   퇴원
# 5441    해외 접촉(중국 우한시)   1/30   중랑구   퇴원
# 5442    해외 접촉(중국 우한시)   1/24   강서구   퇴원
#
# [5443 rows x 6 columns]

# %%
df = df.sort_values(["연번"], ascending=False)

# %%
df.head()
# Out:
#                                                      연번   환자번호        감염경로  \
# 4444  999  <tr>  <td class="tdl" colspan="5">  <p>이동...  11817     리치웨이 관련
# 4445  998  <tr>  <td class="tdl" colspan="5">  <p>이동...  11816  kb 생명보험 관련
# 4446  997  <tr>  <td class="tdl" colspan="5">  <p>이동...  11826        확인 중
# 4447  996  <tr>  <td class="tdl" colspan="5">  <p>이동...  11812        확인 중
# 4448  995  <tr>  <td class="tdl" colspan="5">  <p>이동...  11791     리치웨이 관련
#
#        확진일   거주지 퇴원현황
# 4444  6/08   관악구   퇴원
# 4445  6/08   중랑구   퇴원
# 4446  6/08  서대문구   사망
# 4447  6/05   강동구   퇴원
# 4448  6/07   양천구   퇴원

# %%
df.tail()
# Out:
#                                                      연번   환자번호           감염경로  \
# 4442  1001  <tr>  <td class="tdl" colspan="5">  <p>이...  11821           확인 중
# 4443  1000  <tr>  <td class="tdl" colspan="5">  <p>이...  11851   해외 접촉 추정(미국)
# 5343  100  <tr>  <td class="tdl" colspan="5">  <p>이동...   5377        동대문구 관련
# 5433  10  <tr>  <td class="tdl" colspan="5">  <p>이동경...     21          #6 접촉
# 5442  1  <tr>  <td class="tdl" colspan="5">  <p>이동경로...      2  해외 접촉(중국 우한시)
#
#        확진일   거주지 퇴원현황
# 4442  6/08   강서구   퇴원
# 4443  6/08   서초구   퇴원
# 5343   3/3  동대문구   퇴원
# 5433   2/5   성북구   퇴원
# 5442  1/24   강서구   퇴원
